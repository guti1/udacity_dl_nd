# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6426 0.2479 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6574 0.2535 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5305 0.2516 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5835 0.2560 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4894 0.2777 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5258 0.2608 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5434 0.2865 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5534 0.2752 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4814 0.2966 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4437 0.2430 sec/batch
# Nearest to than: transjordan, sanitary, medline, fracturing, snowflakes, slavish, intestines, countrymen,
# Nearest to been: crucial, birmingham, nawab, conventionally, bracelets, culled, serbo, names,
# Nearest to was: struma, eclac, serfs, abbott, fragrant, returnees, moldovan, standout,
# Nearest to from: element, caster, understood, orr, glorioso, cemetery, portrayed, splits,
# Nearest to and: contender, breslau, shipman, lookup, screenings, defensible, safely, jahangir,
# Nearest to they: rupert, andalus, successions, uzziah, kadima, laconic, eridanus, bullfighting,
# Nearest to which: indulgences, amphion, sinful, cabin, degeneracy, examiners, scarpa, catalysed,
# Nearest to also: vernacular, carter, tights, lee, madurese, all, pamir, straps,
# Nearest to file: intoxication, hypotension, amniocentesis, abundances, durians, tommie, inflating, kurzweil,
# Nearest to grand: indonesia, avi, canyon, venosus, hypoxia, ariosto, mellow, directx,
# Nearest to issue: pain, commemoration, ferrigno, watchmaker, amphitryon, muslim, viability, sadd,
# Nearest to scale: bateson, stug, archiepiscopal, despaired, legislator, feldheim, retaliate, opencyc,
# Nearest to shown: disappointed, norrath, denatured, trainers, sappers, descriptio, uric, ferrari,
# Nearest to know: shabazz, disbelief, funny, herds, delores, derision, forgetful, aurangzeb,
# Nearest to square: greaves, droppings, inhibitors, artistes, ssy, daft, vectorborne, bolshevism,
# Nearest to writers: hsu, corvus, manager, embryo, operative, nanaimo, binds, wap,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4702 0.2727 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3858 0.2570 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3150 0.2552 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2626 0.2332 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2169 0.2538 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1507 0.2398 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0874 0.2312 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0539 0.2289 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9823 0.2307 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9966 0.2358 sec/batch
# Nearest to than: germany, sponsorships, photons, transjordan, forging, long, devices, quatre,
# Nearest to been: crucial, truth, names, conventionally, ur, birmingham, serbo, service,
# Nearest to was: eclac, struma, dozen, proved, abbott, short, serfs, across,
# Nearest to from: understood, literally, element, portrayed, decisions, full, extant, animals,
# Nearest to and: contender, lookup, safely, defensible, simpler, breslau, pauper, achieve,
# Nearest to they: rupert, economic, arranged, kadima, ohio, vendor, andalus, arguments,
# Nearest to which: branch, cabin, sinful, indulgences, statue, values, reading, catalysed,
# Nearest to also: vernacular, all, lee, usage, with, carter, visiting, straps,
# Nearest to file: intoxication, amniocentesis, hypotension, eighteenth, tommie, inflating, gained, democr,
# Nearest to grand: avi, canyon, indonesia, venosus, hypoxia, neville, desperately, contributors,
# Nearest to issue: muslim, pain, commemoration, check, passing, massive, p, posthumously,
# Nearest to scale: bateson, depends, se, opencyc, line, stug, despaired, psychotherapists,
# Nearest to shown: disappointed, norrath, denatured, conference, aids, santiago, centers, jarrett,
# Nearest to know: funny, disbelief, mann, exhibition, algorithms, herds, shabazz, capitals,
# Nearest to square: greaves, droppings, reported, occupies, southern, needs, inhibitors, artistes,
# Nearest to writers: manager, hsu, nanaimo, embryo, handguns, virtually, most, treasures,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9397 0.2451 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9056 0.2634 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8800 0.3084 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8684 0.2386 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8253 0.2358 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7943 0.2286 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8015 0.2274 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7736 0.2276 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7597 0.2344 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7818 0.2319 sec/batch
# Nearest to than: forging, intestines, sanitary, transjordan, sponsorships, photons, fischer, liturgy,
# Nearest to been: conventionally, birmingham, truth, crucial, names, culled, televised, serbo,
# Nearest to was: eclac, dozen, standout, proved, abbott, outraged, prominent, struma,
# Nearest to from: understood, extant, regularity, animals, oblique, portrayed, literally, element,
# Nearest to and: lookup, contender, safely, semiconductor, simpler, breslau, decrees, screenings,
# Nearest to they: arranged, rupert, andalus, economic, successions, vendor, arguments, meaningless,
# Nearest to which: cabin, indulgences, sinful, branch, statue, aloud, boiled, disagree,
# Nearest to also: lee, carter, vernacular, visiting, all, antics, west, reproduction,
# Nearest to file: intoxication, tommie, hypotension, eighteenth, amniocentesis, democr, inflating, abundances,
# Nearest to grand: indonesia, avi, canyon, neville, enter, hypoxia, forbids, venosus,
# Nearest to issue: muslim, pain, commemoration, posthumously, generosity, viability, analyze, codes,
# Nearest to scale: bateson, se, helicopters, depends, line, modernist, stug, archiepiscopal,
# Nearest to shown: disappointed, denatured, norrath, attractiveness, node, aids, ferrari, proceeding,
# Nearest to know: funny, disbelief, exhibition, algorithms, mann, cylindrical, herds, forgetful,
# Nearest to square: greaves, droppings, reported, occupies, inhibitors, rising, needs, methodologies,
# Nearest to writers: manager, hsu, handguns, operative, embryo, virtually, corvus, sewing,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7752 0.2430 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7602 0.2363 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7025 0.2399 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7099 0.2312 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7315 0.2338 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6851 0.2312 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7111 0.2303 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7140 0.2264 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7135 0.2244 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6448 0.2241 sec/batch
# Nearest to than: intestines, sanitary, transjordan, forging, countrymen, sponsorships, composition, fracturing,
# Nearest to been: truth, conventionally, birmingham, squeeze, priscilla, culled, crucial, legislatures,
# Nearest to was: standout, eclac, outraged, midget, proved, dozen, abbott, prominent,
# Nearest to from: regularity, extant, portrayed, orr, animals, oblique, faire, infantry,
# Nearest to and: contender, lookup, defensible, safely, jahangir, shipman, semiconductor, breslau,
# Nearest to they: successions, arranged, vendor, meaningless, andalus, uzziah, arguments, kadima,
# Nearest to which: cabin, indulgences, aloud, sinful, degeneracy, persecuted, trash, boiled,
# Nearest to also: carter, vernacular, visiting, lee, all, reproduction, affiliation, usage,
# Nearest to file: intoxication, tommie, hypotension, abundances, democr, inflating, amniocentesis, eighteenth,
# Nearest to grand: indonesia, avi, canyon, venosus, heisman, forbids, hypoxia, enter,
# Nearest to issue: pain, muslim, commemoration, generosity, viability, codes, posthumously, ferrigno,
# Nearest to scale: bateson, archiepiscopal, helicopters, modernist, se, depends, korps, honoring,
# Nearest to shown: disappointed, denatured, norrath, attractiveness, node, ferrari, aids, insecta,
# Nearest to know: funny, disbelief, algorithms, exhibition, cylindrical, herds, forgetful, mann,
# Nearest to square: greaves, droppings, reported, occupies, inhibitors, rising, artistes, methodologies,
# Nearest to writers: hsu, manager, handguns, operative, corvus, treasures, cleopatra, judah,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6613 0.2244 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6375 0.2295 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6177 0.2283 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6294 0.2288 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6304 0.2278 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6248 0.2299 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6034 0.1608 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5490 0.2308 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5136 0.2326 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5247 0.2333 sec/batch
# Nearest to than: intestines, sanitary, composition, transjordan, deterrent, countrymen, sponsorships, fracturing,
# Nearest to been: conventionally, truth, culled, birmingham, sabbatical, serbo, bracelets, nawab,
# Nearest to was: standout, eclac, midget, proved, aptitude, outraged, prominent, returnees,
# Nearest to from: regularity, splits, extant, animals, faire, orr, caster, portrayed,
# Nearest to and: contender, lookup, safely, defensible, screenings, semiconductor, jahangir, tama,
# Nearest to they: successions, arranged, arguments, meaningless, uzziah, vendor, andalus, laconic,
# Nearest to which: aloud, cabin, indulgences, degeneracy, propellant, trash, boiled, sinful,
# Nearest to also: carter, lee, vernacular, visiting, macfarquhar, all, reproduction, disinterest,
# Nearest to file: tommie, intoxication, hypotension, democr, abundances, menu, inflating, amniocentesis,
# Nearest to grand: indonesia, avi, venosus, canyon, limelight, neville, heisman, hypoxia,
# Nearest to issue: pain, muslim, viability, commemoration, convective, generosity, watchmaker, codes,
# Nearest to scale: bateson, depends, archiepiscopal, modernist, line, helicopters, psychotherapists, busby,
# Nearest to shown: disappointed, denatured, norrath, attractiveness, insecta, sappers, awake, descriptio,
# Nearest to know: disbelief, funny, cylindrical, forgetful, algorithms, ontological, exhibition, copies,
# Nearest to square: greaves, occupies, reported, droppings, inhibitors, artistes, minnesotans, inland,
# Nearest to writers: hsu, operative, manager, handguns, corvus, cleopatra, webster, folktale,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4962 0.2349 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5019 0.2337 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4969 0.2341 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5011 0.2325 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5115 0.2309 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4891 0.2316 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4406 0.2286 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3851 0.2343 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4232 0.2317 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4236 0.2322 sec/batch
# Nearest to than: deterrent, sanitary, composition, intestines, fracturing, snowflakes, transjordan, sponsorships,
# Nearest to been: conventionally, truth, culled, bracelets, nawab, vadis, foresight, serbo,
# Nearest to was: standout, midget, eclac, outraged, became, proved, childhood, aptitude,
# Nearest to from: regularity, splits, extant, caster, hou, qm, portrayed, disorganized,
# Nearest to and: lookup, contender, semiconductor, jahangir, defensible, safely, umlaut, fifo,
# Nearest to they: successions, arranged, uzziah, arguments, vendor, laconic, meaningless, ahasuerus,
# Nearest to which: aloud, cabin, indulgences, propellant, curfews, degeneracy, disagree, scarpa,
# Nearest to also: brentwood, carter, vernacular, usage, undress, reproduction, lee, macfarquhar,
# Nearest to file: hypotension, tommie, menu, abundances, intoxication, inflating, democr, allow,
# Nearest to grand: indonesia, avi, venosus, neville, heisman, canyon, mellow, ariosto,
# Nearest to issue: pain, muslim, convective, treaties, generosity, commemoration, viability, watchmaker,
# Nearest to scale: bateson, depends, helicopters, archiepiscopal, line, stug, abidjan, korps,
# Nearest to shown: disappointed, denatured, uric, attractiveness, norrath, node, sappers, insecta,
# Nearest to know: disbelief, funny, cylindrical, forgetful, algorithms, copies, ontological, apparition,
# Nearest to square: occupies, greaves, inland, reported, temperate, droppings, rising, minnesotans,
# Nearest to writers: operative, hsu, corvus, handguns, cleopatra, folktale, manager, webster,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4310 0.2342 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3899 0.2339 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4411 0.2308 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4125 0.2329 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4371 0.2299 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4293 0.2324 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3851 0.2445 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3526 0.2716 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4342 0.2401 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3571 0.2577 sec/batch
# Nearest to than: deterrent, sanitary, intestines, fracturing, composition, snowflakes, transjordan, sponsorships,
# Nearest to been: conventionally, culled, bracelets, nawab, truth, vadis, lemurs, priscilla,
# Nearest to was: midget, standout, proved, eclac, outraged, eamonn, mindelo, backdrop,
# Nearest to from: regularity, qm, tabled, hou, caster, animals, extant, faire,
# Nearest to and: lookup, safely, contender, semiconductor, pauper, defensible, fifo, niles,
# Nearest to they: successions, arranged, vendor, uzziah, laconic, ahasuerus, arguments, executable,
# Nearest to which: aloud, cabin, disagree, curfews, indulgences, propellant, scarpa, amharic,
# Nearest to also: brentwood, vernacular, carter, undress, usage, macfarquhar, visiting, reproduction,
# Nearest to file: menu, hypotension, allow, tommie, abundances, exponential, inflating, spl,
# Nearest to grand: indonesia, avi, venosus, heisman, mellow, canyon, neville, electrics,
# Nearest to issue: pain, muslim, convective, treaties, watchmaker, peace, countenance, generosity,
# Nearest to scale: depends, archiepiscopal, bateson, line, helicopters, signatures, abidjan, sound,
# Nearest to shown: disappointed, norrath, denatured, uric, sappers, axis, node, attractiveness,
# Nearest to know: disbelief, funny, copies, cylindrical, ontological, forgetful, essentialism, nilpotent,
# Nearest to square: occupies, reported, greaves, minnesotans, temperate, inhibitors, vaporization, inland,
# Nearest to writers: corvus, folktale, operative, cleopatra, handguns, webster, hsu, judah,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3722 0.2576 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3567 0.2525 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3560 0.2379 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3656 0.2543 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3915 0.2337 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3672 0.2426 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3821 0.2515 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3790 0.2247 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3423 0.2228 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3434 0.2198 sec/batch
# Nearest to than: sanitary, deterrent, intestines, snowflakes, transjordan, composition, tasman, limitless,
# Nearest to been: conventionally, bracelets, culled, truth, laborer, nawab, sabbatical, sorceress,
# Nearest to was: midget, standout, proved, wendover, eamonn, bofors, became, eclac,
# Nearest to from: regularity, hou, tabled, qm, extant, immunology, splits, waw,
# Nearest to and: lookup, contender, pauper, blurs, jahangir, decrees, recklessly, safely,
# Nearest to they: successions, arranged, ahasuerus, uzziah, bribe, laconic, vendor, unfretted,
# Nearest to which: aloud, cabin, disagree, scarpa, amharic, propellant, curfews, the,
# Nearest to also: brentwood, usage, macfarquhar, vernacular, undress, carter, hearsay, disinterest,
# Nearest to file: menu, allow, access, hypotension, abundances, tommie, exponential, metadata,
# Nearest to grand: avi, indonesia, venosus, heisman, canyon, neville, miscommunication, gillian,
# Nearest to issue: pain, muslim, treaties, peace, watchmaker, generosity, incompetent, convective,
# Nearest to scale: archiepiscopal, helicopters, depends, bateson, korps, abidjan, signatures, banana,
# Nearest to shown: disappointed, insecta, norrath, denatured, uric, node, descriptio, attractiveness,
# Nearest to know: disbelief, funny, essentialism, cylindrical, forgetful, copies, ontological, nilpotent,
# Nearest to square: occupies, reported, greaves, vaporization, minnesotans, temperate, photovoltaic, inland,
# Nearest to writers: corvus, webster, folktale, cleopatra, operative, hsu, handguns, doth,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3324 0.2230 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2933 0.2264 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3631 0.2424 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4086 0.2362 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3969 0.2389 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2812 0.2361 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3125 0.2371 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3221 0.2362 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2173 0.2408 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3262 0.2419 sec/batch
# Nearest to than: sanitary, transjordan, snowflakes, deterrent, composition, limitless, tasman, intestines,
# Nearest to been: conventionally, bracelets, culled, sorceress, nawab, laborer, arresting, truth,
# Nearest to was: midget, proved, eamonn, standout, marred, wendover, became, once,
# Nearest to from: regularity, tabled, hou, waw, qm, extant, caster, literally,
# Nearest to and: lookup, picot, rif, recklessly, defensible, pauper, contender, jahangir,
# Nearest to they: successions, arranged, laconic, uzziah, ahasuerus, bribe, sprung, unfretted,
# Nearest to which: aloud, cabin, amharic, majilis, scarpa, disagree, curfews, zodiac,
# Nearest to also: usage, brentwood, vernacular, undress, macfarquhar, carter, hearsay, homing,
# Nearest to file: menu, access, allow, hypotension, abundances, extensions, democr, metadata,
# Nearest to grand: avi, indonesia, ariosto, venosus, canyon, heisman, neville, gillian,
# Nearest to issue: pain, muslim, questioning, watchmaker, treaties, peace, incompetent, neoptolemus,
# Nearest to scale: depends, archiepiscopal, signatures, mandolins, helicopters, abidjan, bateson, sound,
# Nearest to shown: disappointed, norrath, denatured, insecta, descriptio, uric, attractiveness, sappers,
# Nearest to know: disbelief, funny, essentialism, cylindrical, ontological, nilpotent, copies, forgetful,
# Nearest to square: occupies, minnesotans, vaporization, reported, greaves, missouri, inland, kilometres,
# Nearest to writers: folktale, webster, corvus, cleopatra, essayists, hsu, handguns, operative,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3105 0.2273 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2705 0.2403 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3475 0.0953 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2487 0.2376 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2082 0.2424 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2074 0.2366 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2436 0.2451 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2251 0.2403 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2402 0.2496 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1873 0.2452 sec/batch
# Nearest to than: sanitary, deterrent, tasman, transjordan, snowflakes, composition, medline, intestines,
# Nearest to been: conventionally, bracelets, culled, nawab, laborer, vadis, arresting, sorceress,
# Nearest to was: midget, proved, marred, eamonn, standout, timezone, wendover, first,
# Nearest to from: regularity, tabled, splits, waw, hou, russification, portugese, qm,
# Nearest to and: lookup, picot, aquaculture, safely, reappointed, blurs, rif, incline,
# Nearest to they: arranged, successions, laconic, ahasuerus, sprung, bribe, uzziah, eridanus,
# Nearest to which: aloud, cabin, curfews, scarpa, majilis, the, amharic, reproached,
# Nearest to also: usage, brentwood, undress, vernacular, hearsay, carter, macfarquhar, west,
# Nearest to file: menu, access, allow, metadata, extensions, filesystem, cpu, data,
# Nearest to grand: avi, ariosto, gillian, indonesia, venosus, canyon, electrics, mayakovsky,
# Nearest to issue: pain, muslim, questioning, watchmaker, roundly, gamespot, convective, incompetent,
# Nearest to scale: signatures, sound, archiepiscopal, depends, mandolins, helicopters, stug, bateson,
# Nearest to shown: disappointed, norrath, denatured, insecta, uric, descriptio, diagram, sappers,
# Nearest to know: disbelief, funny, ontological, essentialism, forgetful, mann, cylindrical, nilpotent,
# Nearest to square: occupies, minnesotans, vaporization, reported, missouri, kilometres, greaves, temperate,
# Nearest to writers: webster, folktale, cleopatra, essayists, corvus, science, novelists, hsu,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2490 0.2448 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2490 0.2302 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2225 0.2445 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1366 0.2425 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1610 0.2508 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1610 0.2660 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1789 0.2451 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1770 0.2342 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1886 0.2348 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1818 0.2403 sec/batch
# Nearest to than: deterrent, sanitary, snowflakes, tasman, limitless, composition, sponsorships, affan,
# Nearest to been: conventionally, bracelets, culled, nawab, arresting, laborer, vadis, sorceress,
# Nearest to was: midget, proved, marred, mindelo, eamonn, resumed, standout, wendover,
# Nearest to from: regularity, caster, tabled, waw, literally, exclusionary, qm, hou,
# Nearest to and: lookup, blurs, niles, akshara, picot, aquaculture, umlaut, nanotubes,
# Nearest to they: arranged, successions, sprung, laconic, bribe, ahasuerus, watchers, suggest,
# Nearest to which: aloud, cabin, curfews, the, firework, majilis, amharic, reproached,
# Nearest to also: usage, undress, brentwood, west, see, hearsay, inventors, macfarquhar,
# Nearest to file: menu, allow, access, metadata, extensions, abundances, filesystem, files,
# Nearest to grand: ariosto, avi, indonesia, canyon, venosus, galante, gillian, electrics,
# Nearest to issue: pain, muslim, convective, gamespot, watchmaker, propter, questioning, incompetent,
# Nearest to scale: depends, mandolins, signatures, archiepiscopal, sound, helicopters, legislator, scarp,
# Nearest to shown: disappointed, norrath, denatured, uric, insecta, descriptio, sappers, axis,
# Nearest to know: disbelief, funny, essentialism, ontological, cylindrical, forgetful, predicates, nilpotent,
# Nearest to square: occupies, vaporization, missouri, minnesotans, kilometres, temperate, greaves, reported,
# Nearest to writers: folktale, webster, essayists, novelists, cleopatra, corvus, science, fedora,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1919 0.2372 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2261 0.2388 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1637 0.2326 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1498 0.2449 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1881 0.2353 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1865 0.2228 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2261 0.2300 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1414 0.2222 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1455 0.2241 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1845 0.2208 sec/batch
# Nearest to than: sanitary, snowflakes, deterrent, tasman, composition, limitless, years, hurling,
# Nearest to been: culled, conventionally, bracelets, birka, nawab, laborer, sorceress, arresting,
# Nearest to was: midget, proved, marred, eamonn, mindelo, standout, became, resumed,
# Nearest to from: regularity, waw, hou, qm, tabled, caster, kam, extant,
# Nearest to and: lookup, blurs, picot, akshara, elusive, aquaculture, safely, pauper,
# Nearest to they: arranged, sprung, successions, laconic, bribe, ahasuerus, watchers, vidzeme,
# Nearest to which: aloud, cabin, curfews, majilis, the, amharic, firework, reproached,
# Nearest to also: usage, brentwood, undress, see, vernacular, macfarquhar, carter, west,
# Nearest to file: menu, extensions, allow, metadata, filesystem, access, files, format,
# Nearest to grand: ariosto, avi, canyon, electrics, indonesia, miscommunication, cryptosystems, venosus,
# Nearest to issue: pain, muslim, watchmaker, incompetent, roundly, propter, questioning, treaties,
# Nearest to scale: mandolins, depends, archiepiscopal, signatures, helicopters, sound, scarp, korps,
# Nearest to shown: disappointed, norrath, uric, insecta, denatured, sappers, axis, descriptio,
# Nearest to know: disbelief, funny, essentialism, ontological, cylindrical, entertain, predicates, nilpotent,
# Nearest to square: occupies, vaporization, minnesotans, missouri, greaves, kilometres, reported, intermediate,
# Nearest to writers: folktale, essayists, webster, novelists, science, corvus, cleopatra, poets,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2037 0.2277 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1655 0.2364 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1946 0.2314 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1824 0.2524 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1573 0.2413 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1610 0.2520 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1621 0.2396 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1231 0.2286 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1713 0.2249 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2295 0.2252 sec/batch
# Nearest to than: sanitary, years, deterrent, snowflakes, missionaries, transjordan, composition, gracious,
# Nearest to been: birka, conventionally, laborer, sorceress, culled, bracelets, nawab, priscilla,
# Nearest to was: proved, midget, eamonn, marred, he, first, impressed, resumed,
# Nearest to from: tabled, hou, waw, personages, bible, literally, extant, sultanate,
# Nearest to and: in, reappointed, picot, the, aquaculture, with, decrees, inez,
# Nearest to they: arranged, successions, sprung, laconic, bayonet, mcdowell, ahasuerus, uzziah,
# Nearest to which: aloud, the, majilis, cabin, coalesce, reproached, curfews, amharic,
# Nearest to also: usage, see, brentwood, undress, glissando, macfarquhar, inventors, carter,
# Nearest to file: menu, extensions, allow, metadata, filesystem, access, democr, downloads,
# Nearest to grand: ariosto, electrics, mayakovsky, avi, miscommunication, cryptosystems, canyon, venosus,
# Nearest to issue: pain, muslim, watchmaker, propter, roundly, repetition, incompetent, questioning,
# Nearest to scale: mandolins, archiepiscopal, sound, korps, signatures, feldheim, depends, scarp,
# Nearest to shown: disappointed, norrath, uric, denatured, hertfordshire, insecta, descriptio, subjection,
# Nearest to know: disbelief, funny, essentialism, ontological, entertain, predicates, nilpotent, mann,
# Nearest to square: occupies, vaporization, missouri, greaves, minnesotans, kilometres, reported, temperate,
# Nearest to writers: novelists, folktale, webster, essayists, science, cleopatra, corvus, poets,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2586 0.2254 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1600 0.2241 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1287 0.2221 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1404 0.2231 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0319 0.2276 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1618 0.2254 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1285 0.2279 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1569 0.2515 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1655 0.0251 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1350 0.2301 sec/batch
# Nearest to than: snowflakes, composition, deterrent, sanitary, years, limitless, missionaries, minus,
# Nearest to been: conventionally, bracelets, birka, culled, priscilla, sorceress, exalts, arresting,
# Nearest to was: proved, midget, booty, impressed, dromedary, he, became, angevin,
# Nearest to from: hou, regularity, waw, tabled, mt, ichij, caster, qm,
# Nearest to and: in, with, the, blurs, picot, lookup, aquaculture, hillside,
# Nearest to they: arranged, unfretted, eridanus, bayonet, vidzeme, sprung, successions, watchers,
# Nearest to which: aloud, the, cabin, majilis, amharic, alternator, curfews, carisbrooke,
# Nearest to also: usage, see, brentwood, undress, with, glissando, inventors, consistently,
# Nearest to file: menu, extensions, filesystem, metadata, allow, access, files, democr,
# Nearest to grand: ariosto, mayakovsky, electrics, cryptosystems, avi, miscommunication, venosus, indonesia,
# Nearest to issue: muslim, pain, roundly, watchmaker, propter, repetition, gamespot, codes,
# Nearest to scale: signatures, sound, mandolins, archiepiscopal, depends, feldheim, explicate, scarp,
# Nearest to shown: disappointed, norrath, uric, denatured, insecta, axis, diagram, magnetically,
# Nearest to know: disbelief, funny, essentialism, predicates, entertain, ontological, mann, cylindrical,
# Nearest to square: occupies, missouri, vaporization, minnesotans, greaves, kilometres, reported, rising,
# Nearest to writers: novelists, webster, folktale, essayists, science, cleopatra, corvus, poets,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0698 0.2352 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0794 0.2576 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0968 0.2824 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0595 0.3013 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0708 0.2332 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0157 0.2194 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1067 0.2530 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1029 0.2504 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1101 0.2531 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0579 0.2646 sec/batch
# Nearest to than: deterrent, years, snowflakes, sanitary, composition, tasman, missionaries, mm,
# Nearest to been: conventionally, birka, bracelets, nawab, culled, arresting, priscilla, sabbatical,
# Nearest to was: proved, midget, booty, became, first, he, angevin, fujitsu,
# Nearest to from: regularity, waw, hou, tabled, ichij, personages, qm, the,
# Nearest to and: in, the, with, blurs, picot, lookup, akshara, also,
# Nearest to they: arranged, unfretted, a, vidzeme, sprung, ahasuerus, bayonet, watchers,
# Nearest to which: aloud, the, amharic, cabin, alternator, majilis, curfews, carisbrooke,
# Nearest to also: usage, see, with, brentwood, undress, and, consistently, inventors,
# Nearest to file: menu, extensions, metadata, allow, filesystem, files, uncompressed, downloads,
# Nearest to grand: ariosto, cryptosystems, electrics, mayakovsky, miscommunication, venosus, canyon, avi,
# Nearest to issue: pain, muslim, repetition, roundly, watchmaker, propter, gamespot, convective,
# Nearest to scale: sound, signatures, mandolins, depends, archiepiscopal, feldheim, explicate, scarp,
# Nearest to shown: disappointed, norrath, denatured, uric, insecta, hertfordshire, diagram, magnetically,
# Nearest to know: disbelief, funny, essentialism, predicates, your, ontological, we, entertain,
# Nearest to square: occupies, missouri, vaporization, minnesotans, greaves, kilometres, rising, reported,
# Nearest to writers: novelists, folktale, essayists, webster, science, natives, poets, corvus,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0480 0.2436 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0220 0.2529 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0294 0.2486 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0320 0.2193 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0809 0.2205 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0615 0.2205 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0009 0.2199 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1131 0.2317 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0808 0.2205 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0395 0.2221 sec/batch
# Nearest to than: years, snowflakes, deterrent, mm, sanitary, composition, missionaries, limitless,
# Nearest to been: birka, conventionally, bracelets, priscilla, nawab, sorceress, culled, arresting,
# Nearest to was: proved, became, midget, booty, he, impressed, first, dromedary,
# Nearest to from: regularity, waw, qm, caster, tabled, mt, semiarid, shearing,
# Nearest to and: in, the, blurs, with, lookup, akshara, elusive, picot,
# Nearest to they: arranged, unfretted, sprung, vidzeme, a, mpaja, bribe, defenders,
# Nearest to which: the, aloud, cabin, majilis, alternator, curfews, reproached, amharic,
# Nearest to also: usage, see, brentwood, undress, with, inventors, surah, kimbundu,
# Nearest to file: menu, filesystem, allow, extensions, files, uncompressed, metadata, tommie,
# Nearest to grand: ariosto, cryptosystems, electrics, canyon, miscommunication, indonesia, venosus, avi,
# Nearest to issue: pain, muslim, watchmaker, propter, roundly, repetition, convective, gamespot,
# Nearest to scale: sound, signatures, mandolins, depends, archiepiscopal, feldheim, shifted, legislator,
# Nearest to shown: disappointed, denatured, norrath, uric, hertfordshire, napier, insecta, axis,
# Nearest to know: disbelief, funny, your, we, predicates, essentialism, ontological, nilpotent,
# Nearest to square: occupies, missouri, vaporization, kilometres, greaves, rising, minnesotans, temperate,
# Nearest to writers: novelists, folktale, essayists, poets, webster, science, natives, corvus,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0556 0.2236 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0959 0.2194 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0691 0.2198 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0844 0.2193 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.1018 0.2189 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0133 0.2218 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0397 0.2209 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0875 0.2210 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1130 0.2579 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0759 0.2584 sec/batch
# Nearest to than: years, snowflakes, missionaries, composition, gracious, dalits, deterrent, qualify,
# Nearest to been: conventionally, birka, culled, priscilla, frodo, nawab, arresting, exalts,
# Nearest to was: became, proved, he, booty, angevin, impressed, first, serfs,
# Nearest to from: waw, hou, qm, regularity, the, lempira, sultanate, tabled,
# Nearest to and: in, the, with, blurs, picot, also, communes, lookup,
# Nearest to they: arranged, unfretted, sprung, watchers, vidzeme, ahasuerus, a, bribe,
# Nearest to which: the, aloud, carisbrooke, majilis, amharic, alternator, cabin, itasca,
# Nearest to also: see, usage, brentwood, with, and, undress, kimbundu, disinterest,
# Nearest to file: menu, filesystem, files, uncompressed, metadata, extensions, allow, server,
# Nearest to grand: ariosto, electrics, cryptosystems, canyon, indonesia, bags, miscommunication, mayakovsky,
# Nearest to issue: muslim, propter, pain, repetition, roundly, watchmaker, gamespot, infringement,
# Nearest to scale: sound, mandolins, signatures, archiepiscopal, depends, explicate, feldheim, scarp,
# Nearest to shown: disappointed, norrath, hertfordshire, napier, insecta, denatured, axis, diagram,
# Nearest to know: disbelief, funny, your, we, predicates, essentialism, ontological, our,
# Nearest to square: occupies, missouri, vaporization, greaves, minnesotans, rising, kilometres, bullpen,
# Nearest to writers: novelists, folktale, essayists, natives, webster, science, poets, operative,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0303 0.2633 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0112 0.2603 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0470 0.2559 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0879 0.2623 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0429 0.2558 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1131 0.2399 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1136 0.2366 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0705 0.2515 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0301 0.2699 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0497 0.2938 sec/batch
# Nearest to than: years, composition, snowflakes, limitless, dalits, missionaries, evenly, more,
# Nearest to been: birka, conventionally, culled, priscilla, livelihoods, btr, frodo, nawab,
# Nearest to was: proved, became, first, he, angevin, booty, impressed, midget,
# Nearest to from: waw, regularity, qm, mt, hou, semiarid, tabled, hauck,
# Nearest to and: in, the, with, also, blurs, picot, lookup, as,
# Nearest to they: arranged, unfretted, sprung, watchers, laconic, mcdowell, morisco, receive,
# Nearest to which: the, aloud, amharic, majilis, carisbrooke, adonai, exogamy, suspended,
# Nearest to also: see, usage, brentwood, and, kimbundu, undress, jiao, restrictive,
# Nearest to file: menu, filesystem, files, uncompressed, tommie, allow, extensions, metadata,
# Nearest to grand: ariosto, cryptosystems, electrics, mayakovsky, canyon, rohan, indonesia, bags,
# Nearest to issue: muslim, roundly, propter, watchmaker, repetition, pain, menzies, gamespot,
# Nearest to scale: sound, signatures, mandolins, archiepiscopal, depends, korps, legislator, ambrogio,
# Nearest to shown: disappointed, norrath, napier, hertfordshire, diagram, subjection, insecta, descriptio,
# Nearest to know: disbelief, funny, your, we, essentialism, predicates, our, entertain,
# Nearest to square: occupies, missouri, vaporization, greaves, rising, kilometres, minnesotans, cammag,
# Nearest to writers: novelists, essayists, folktale, natives, poets, science, webster, operative,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0027 0.2575 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9955 0.2422 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0407 0.2401 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0220 0.2329 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0657 0.2435 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0496 0.1836 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0134 0.2265 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9939 0.2247 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0343 0.2283 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9712 0.2265 sec/batch
# Nearest to than: years, composition, snowflakes, more, deterrent, evenly, dalits, mm,
# Nearest to been: conventionally, culled, birka, priscilla, bracelets, livelihoods, frodo, btr,
# Nearest to was: first, proved, he, became, booty, angevin, lenthall, impressed,
# Nearest to from: qm, the, mt, regularity, waw, tabled, hou, ichij,
# Nearest to and: in, the, with, also, blurs, picot, of, as,
# Nearest to they: arranged, unfretted, came, sprung, watchers, vidzeme, torment, receive,
# Nearest to which: the, aloud, amharic, reproached, cabin, carisbrooke, spores, adonai,
# Nearest to also: see, usage, and, brentwood, kimbundu, with, glissando, consistently,
# Nearest to file: menu, filesystem, files, uncompressed, patriotic, tommie, format, extensions,
# Nearest to grand: ariosto, cryptosystems, electrics, canyon, mayakovsky, bags, rohan, kinross,
# Nearest to issue: muslim, roundly, repetition, propter, gamespot, pain, watchmaker, atlas,
# Nearest to scale: signatures, mandolins, sound, scales, depends, archiepiscopal, electromechanical, congregationalist,
# Nearest to shown: disappointed, norrath, hertfordshire, napier, subjection, insecta, uric, magnetically,
# Nearest to know: disbelief, your, funny, predicates, we, essentialism, ontological, wickedness,
# Nearest to square: occupies, missouri, vaporization, rising, greaves, minnesotans, kilometres, bullpen,
# Nearest to writers: novelists, essayists, folktale, poets, natives, science, webster, operative,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0027 0.2269 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9329 0.2258 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0337 0.2254 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0183 0.2297 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0157 0.2250 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9782 0.2264 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9019 0.2243 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9849 0.2253 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9680 0.2236 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9660 0.2267 sec/batch
# Nearest to than: years, composition, more, dalits, missionaries, deterrent, mm, evenly,
# Nearest to been: conventionally, birka, culled, btr, livelihoods, priscilla, lemurs, nawab,
# Nearest to was: first, proved, became, booty, angevin, lenthall, he, penciller,
# Nearest to from: qm, regularity, the, waw, mt, tabled, penile, ichij,
# Nearest to and: in, the, with, also, of, blurs, picot, as,
# Nearest to they: arranged, sprung, vidzeme, unfretted, came, watchers, torment, defeat,
# Nearest to which: the, aloud, amharic, spores, reproached, carisbrooke, alternator, exogamy,
# Nearest to also: see, and, usage, kimbundu, with, brentwood, restrictive, jiao,
# Nearest to file: menu, filesystem, files, uncompressed, patriotic, tommie, downloads, allow,
# Nearest to grand: ariosto, cryptosystems, electrics, bags, canyon, rohan, derision, indonesia,
# Nearest to issue: muslim, propter, repetition, roundly, pain, gamespot, atlas, ifa,
# Nearest to scale: signatures, mandolins, sound, scales, archiepiscopal, ambrogio, congregationalist, depends,
# Nearest to shown: disappointed, uric, norrath, diagram, hertfordshire, axis, denatured, insecta,
# Nearest to know: disbelief, your, we, funny, predicates, our, ontological, mann,
# Nearest to square: occupies, missouri, vaporization, rising, kilometres, greaves, cammag, minnesotans,
# Nearest to writers: novelists, essayists, folktale, poets, natives, operative, science, webster,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9933 0.2339 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0297 0.2245 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9809 0.2417 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0146 0.2282 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0324 0.2340 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9592 0.2283 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9808 0.2371 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0151 0.2283 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9988 0.2486 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0318 0.2861 sec/batch
# Nearest to than: years, composition, dalits, qualify, missionaries, evenly, gracious, more,
# Nearest to been: birka, culled, conventionally, livelihoods, priscilla, presenters, btr, exalts,
# Nearest to was: became, he, first, proved, penciller, angevin, later, lenthall,
# Nearest to from: qm, regularity, tabled, the, waw, ichij, shearing, hou,
# Nearest to and: in, the, with, of, also, for, as, blurs,
# Nearest to they: arranged, unfretted, receive, sprung, vidzeme, mpaja, shack, infield,
# Nearest to which: the, aloud, carisbrooke, majilis, alternator, amharic, reproached, tyre,
# Nearest to also: see, usage, and, brentwood, with, kimbundu, jiao, denoted,
# Nearest to file: menu, files, filesystem, tommie, uncompressed, patriotic, allow, downloads,
# Nearest to grand: electrics, cryptosystems, ariosto, bags, canyon, chemie, indonesia, enter,
# Nearest to issue: muslim, repetition, propter, gamespot, roundly, pain, fraud, convective,
# Nearest to scale: mandolins, signatures, sound, scales, ambrogio, archiepiscopal, korps, congregationalist,
# Nearest to shown: disappointed, hertfordshire, norrath, uric, axis, diagram, subjection, napier,
# Nearest to know: disbelief, your, we, our, funny, predicates, mann, dreadful,
# Nearest to square: occupies, vaporization, missouri, greaves, rising, bullpen, kilometres, cammag,
# Nearest to writers: novelists, essayists, natives, poets, folktale, operative, science, webster,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0403 0.2500 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9633 0.2387 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0046 0.2407 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0238 0.2491 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9991 0.2459 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0003 0.2343 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9879 0.2308 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9711 0.2328 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9747 0.2268 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0271 0.2476 sec/batch
# Nearest to than: years, more, missionaries, composition, dalits, evenly, qualify, gracious,
# Nearest to been: birka, conventionally, culled, priscilla, livelihoods, names, btr, presenters,
# Nearest to was: first, became, he, proved, later, angevin, had, booty,
# Nearest to from: the, qm, tabled, waw, mt, regularity, semiarid, ichij,
# Nearest to and: in, the, with, of, also, for, as, picot,
# Nearest to they: arranged, vidzeme, a, unfretted, would, sprung, photophone, receive,
# Nearest to which: the, aloud, carisbrooke, in, majilis, and, amharic, independent,
# Nearest to also: see, and, kimbundu, with, usage, brentwood, restrictive, jiao,
# Nearest to file: menu, files, filesystem, uncompressed, tommie, patriotic, allow, format,
# Nearest to grand: cryptosystems, electrics, ariosto, bags, canyon, derision, enter, chemie,
# ...
# Nearest to also: see, and, kimbundu, with, brentwood, usage, in, restrictive,
# Nearest to file: menu, files, uncompressed, filesystem, tommie, patriotic, format, downloads,
# Nearest to grand: electrics, ariosto, cryptosystems, bags, rohan, canyon, tennis, jock,
# Nearest to issue: muslim, roundly, propter, repetition, gamespot, atlas, review, sadd,
# Nearest to scale: signatures, mandolins, sound, congregationalist, ambrogio, scales, archiepiscopal, electromechanical,
# Nearest to shown: disappointed, diagram, hertfordshire, uric, norrath, subjection, axis, napier,
# Nearest to know: disbelief, your, our, funny, wickedness, we, predicates, mann,
# Nearest to square: occupies, vaporization, missouri, rising, kilometres, greaves, cammag, bullpen,
# Nearest to writers: novelists, essayists, natives, folktale, poets, operative, playwrights, eisner,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 3.9855 0.2487 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 4.0380 0.1383 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.9438 0.2580 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.9257 0.2367 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.9461 0.2406 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.9417 0.2303 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.9243 0.2538 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.9587 0.2311 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.9227 0.2237 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9719 0.2214 sec/batch
# Nearest to than: more, years, missionaries, composition, evenly, mm, dalits, fertility,
# Nearest to been: culled, conventionally, birka, priscilla, names, livelihoods, btr, cilicia,
# Nearest to was: first, he, became, had, later, introduced, proved, booty,
# Nearest to from: qm, the, regularity, ichij, mt, hou, waw, also,
# Nearest to and: in, the, with, also, of, for, as, are,
# Nearest to they: unfretted, came, arranged, a, would, torment, laconic, watchers,
# Nearest to which: the, aloud, carisbrooke, amharic, boiled, spores, exogamy, trash,
# Nearest to also: and, see, with, kimbundu, in, brentwood, usage, from,
# Nearest to file: menu, files, uncompressed, filesystem, tommie, patriotic, downloads, format,
# Nearest to grand: electrics, cryptosystems, ariosto, bags, canyon, jock, derision, rohan,
# Nearest to issue: muslim, roundly, gamespot, repetition, propter, review, atlas, proselytes,
# Nearest to scale: signatures, mandolins, sound, scales, ambrogio, congregationalist, electromechanical, archiepiscopal,
# Nearest to shown: disappointed, hertfordshire, diagram, subjection, uric, axis, norrath, denatured,
# Nearest to know: disbelief, your, our, we, predicates, wickedness, funny, mann,
# Nearest to square: occupies, vaporization, rising, kilometres, missouri, bullpen, cammag, greaves,
# Nearest to writers: novelists, essayists, natives, folktale, poets, operative, playwrights, eisner,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.9524 0.2435 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9787 0.2433 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8485 0.2204 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.9438 0.2220 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.9210 0.2233 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.8553 0.2246 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.9498 0.2238 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.9483 0.2233 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.9415 0.2214 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.9031 0.2222 sec/batch
# Nearest to than: more, years, missionaries, composition, evenly, mm, dalits, factors,
# Nearest to been: birka, culled, conventionally, priscilla, livelihoods, names, qattara, btr,
# Nearest to was: first, became, he, proved, later, introduced, booty, penciller,
# Nearest to from: the, qm, to, regularity, also, penile, posting, ichij,
# Nearest to and: in, with, the, also, of, for, as, are,
# Nearest to they: would, to, came, a, unfretted, sprung, arranged, watchers,
# Nearest to which: the, aloud, trash, carisbrooke, boiled, alternator, amharic, reproached,
# Nearest to also: and, see, with, in, kimbundu, from, usage, restrictive,
# Nearest to file: menu, files, filesystem, uncompressed, tommie, patriotic, downloads, format,
# Nearest to grand: electrics, cryptosystems, ariosto, derision, bags, canyon, jock, indonesia,
# Nearest to issue: propter, atlas, muslim, review, repetition, gamespot, roundly, comedienne,
# Nearest to scale: mandolins, signatures, sound, ambrogio, scales, congregationalist, electromechanical, korps,
# Nearest to shown: disappointed, diagram, hertfordshire, uric, axis, subjection, pearly, norrath,
# Nearest to know: disbelief, our, we, your, predicates, dreadful, mann, wickedness,
# Nearest to square: occupies, vaporization, kilometres, rising, missouri, cammag, greaves, bullpen,
# Nearest to writers: novelists, essayists, poets, folktale, natives, playwrights, eisner, operative,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9989 0.2261 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.9685 0.2262 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.9336 0.2340 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9532 0.2330 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.9593 0.2342 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 4.0259 0.2229 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.9391 0.2311 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.9417 0.2264 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.9325 0.2226 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9572 0.2231 sec/batch
# Nearest to than: years, more, missionaries, evenly, composition, therefore, mm, gracious,
# Nearest to been: birka, culled, conventionally, names, qattara, priscilla, livelihoods, btr,
# Nearest to was: first, he, became, later, introduced, penciller, proved, his,
# Nearest to from: the, qm, also, regularity, hou, tabled, understood, waw,
# Nearest to and: in, the, with, of, also, for, as, are,
# Nearest to they: would, to, unfretted, came, shack, scavengers, sprung, vidzeme,
# Nearest to which: the, aloud, carisbrooke, amharic, has, of, a, hydroxyl,
# Nearest to also: see, and, with, in, kimbundu, from, brentwood, usage,
# Nearest to file: menu, files, tommie, uncompressed, patriotic, nord, filesystem, downloads,
# Nearest to grand: electrics, cryptosystems, ariosto, derision, canyon, bags, jock, indonesia,
# Nearest to issue: propter, muslim, atlas, repetition, review, roundly, gamespot, proselytes,
# Nearest to scale: mandolins, signatures, ambrogio, scales, sound, congregationalist, korps, archiepiscopal,
# Nearest to shown: disappointed, hertfordshire, diagram, subjection, axis, pearly, norrath, uric,
# Nearest to know: disbelief, we, our, your, predicates, dreadful, mann, wickedness,
# Nearest to square: occupies, vaporization, kilometres, rising, missouri, greaves, volterra, bullpen,
# Nearest to writers: novelists, essayists, folktale, poets, natives, playwrights, eisner, operative,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9269 0.2281 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.9488 0.2225 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9575 0.2240 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.9355 0.2184 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.9080 0.3909 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9923 0.3082 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.9530 0.3185 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 4.0015 0.4855 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 4.0288 0.4825 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 4.0137 0.4543 sec/batch
# Nearest to than: more, years, missionaries, composition, evenly, fertility, dalits, gracious,
# Nearest to been: culled, birka, priscilla, conventionally, presenters, livelihoods, names, accusations,
# Nearest to was: first, he, later, became, introduced, in, talked, subsequently,
# Nearest to from: the, qm, hou, tabled, also, to, ichij, mt,
# Nearest to and: in, the, with, of, also, for, as, are,
# Nearest to they: would, unfretted, to, shack, came, scavengers, a, watchers,
# Nearest to which: the, aloud, carisbrooke, amharic, adonai, franconia, initially, in,
# Nearest to also: see, and, in, kimbundu, with, from, restrictive, brentwood,
# Nearest to file: files, tommie, menu, uncompressed, patriotic, nord, filesystem, downloads,
# Nearest to grand: electrics, cryptosystems, ariosto, derision, canyon, jock, bags, indonesia,
# Nearest to issue: roundly, propter, atlas, review, which, muslim, gamespot, reynolds,
# Nearest to scale: mandolins, signatures, ambrogio, congregationalist, archiepiscopal, korps, sound, scales,
# Nearest to shown: disappointed, hertfordshire, diagram, subjection, pearly, axis, uric, norrath,
# Nearest to know: disbelief, your, our, funny, we, wickedness, predicates, dreadful,
# Nearest to square: occupies, vaporization, rising, kilometres, missouri, greaves, volterra, bullpen,
# Nearest to writers: novelists, essayists, natives, poets, folktale, playwrights, eisner, operative,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.9541 0.4269 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.9087 0.4084 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.9312 685.6029 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8100 0.2414 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9723 0.2724 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9210 0.2416 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.9512 0.2399 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9914 0.0453 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.9307 0.2268 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.9007 0.2241 sec/batch
# Nearest to than: more, years, evenly, missionaries, composition, factors, mm, percentage,
# Nearest to been: culled, birka, livelihoods, conventionally, names, qattara, priscilla, presenters,
# Nearest to was: first, later, he, became, introduced, in, autocrat, subsequently,
# Nearest to from: the, qm, also, hou, shearing, to, ichij, regularity,
# Nearest to and: in, the, with, of, also, as, for, to,
# Nearest to they: would, came, unfretted, shack, to, scavengers, abandonment, a,
# Nearest to which: the, aloud, initially, in, carisbrooke, amharic, franconia, trash,
# Nearest to also: and, see, in, with, kimbundu, from, restrictive, brentwood,
# Nearest to file: files, menu, tommie, uncompressed, format, patriotic, nord, filesystem,
# Nearest to grand: electrics, cryptosystems, tennis, ariosto, derision, canyon, jock, indonesia,
# Nearest to issue: atlas, review, muslim, roundly, gamespot, propter, which, repetition,
# Nearest to scale: mandolins, signatures, scales, sound, congregationalist, ambrogio, archiepiscopal, electromechanical,
# Nearest to shown: disappointed, diagram, hertfordshire, pearly, axis, uric, subjection, norrath,
# Nearest to know: disbelief, your, our, we, predicates, mann, wickedness, drummer,
# Nearest to square: occupies, vaporization, kilometres, rising, missouri, cammag, bullpen, greaves,
# Nearest to writers: novelists, essayists, natives, poets, folktale, playwrights, operative, eisner,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8865 0.2277 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.9130 0.2207 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8608 0.2201 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.9062 0.2227 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8608 0.2226 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.8980 0.2258 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.9158 0.2197 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9733 0.2194 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8670 0.2220 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8668 0.2238 sec/batch
# Nearest to than: more, years, missionaries, factors, evenly, composition, mm, fertility,
# Nearest to been: birka, culled, has, names, have, conventionally, livelihoods, qattara,
# Nearest to was: first, later, became, he, introduced, late, had, the,
# Nearest to from: the, to, also, qm, a, in, full, taken,
# Nearest to and: in, the, of, with, also, for, are, as,
# Nearest to they: would, to, came, unfretted, a, scavengers, vidzeme, shack,
# Nearest to which: the, in, aloud, and, a, of, with, initially,
# Nearest to also: and, see, in, with, kimbundu, from, the, as,
# Nearest to file: files, menu, uncompressed, tommie, format, nord, patriotic, filesystem,
# Nearest to grand: electrics, cryptosystems, ariosto, canyon, tennis, derision, indonesia, bags,
# Nearest to issue: atlas, roundly, review, which, muslim, gamespot, reynolds, excel,
# Nearest to scale: mandolins, signatures, congregationalist, scales, ambrogio, sound, korps, archiepiscopal,
# Nearest to shown: disappointed, diagram, hertfordshire, pearly, axis, subjection, uric, norrath,
# Nearest to know: disbelief, your, our, we, predicates, mann, wickedness, want,
# Nearest to square: occupies, kilometres, vaporization, rising, missouri, temperate, cammag, pleasant,
# Nearest to writers: novelists, essayists, natives, folktale, poets, operative, playwrights, eisner,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8592 0.2269 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8239 0.2728 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-130fb168e565> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
